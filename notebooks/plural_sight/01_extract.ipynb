# %% [markdown]
# # Task 1 — Define Source and Extract

# %% [markdown]
# # Pluralsight Content Extraction
#
# ## Objective
#
# This notebook extracts educational article data from Pluralsight's public AI & Data and Cloud blog categories.
#
# The extracted data will be saved as raw JSON files and used as the input for Task 2 — Data Discovery, Profiling and Cleaning.
#
# ### Data Sources
#
# 1. Pluralsight AI & Data
#    https://www.pluralsight.com/resources/blog/ai-and-data
#
# 2. Pluralsight Cloud
#    https://www.pluralsight.com/resources/blog/cloud
#
# The extracted metadata includes:
#
# - Source
# - Category
# - Title
# - Author
# - Publication date
# - Description
# - Tags
# - URL
# - Article content
# - Scraped timestamp

# %% [markdown]
# ## Source Definition
#
# ### Source
# Pluralsight public technology blog.
#
# ### Authentication
# No authentication or API key is required for the public blog pages.
#
# ### Collection Method
# The project uses Python HTTP requests and BeautifulSoup to retrieve and parse publicly accessible HTML pages.
#
# ### Categories
# - AI & Data
# - Cloud
#
# ### Pagination
# The category pages are paginated. The scraper follows category pages and extracts individual article URLs.
#
# ### Rate Limiting
# A delay of 2 seconds is applied between requests to reduce request frequency.
#
# HTTP 429 responses are handled by waiting before retrying.
#
# ### Terms and Usage
# The project is an educational data engineering project. Only publicly available article content and metadata are collected, and the scraper uses a low request rate.

# %%
from datetime import datetime
import json
import os
import time
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
import requests

# %%
BASE_URL = "https://pluralsight.com"

# Tracks both targets and outputs to their explicit folder paths
CATEGORIES = {
    "AI & Data": {
        "url": "https://pluralsight.com/resources/blog/ai-and-data",
        "output": "../../data/raw/pluralsight_ai_data_articles.json",
        "max_pages": 31,
    },
    "Cloud": {
        "url": "https://pluralsight.com/resources/blog/cloud",
        "output": "../../data/raw/pluralsight_cloud_articles.json",
        "max_pages": 47,
    },
}

# Change this to 360 when you are ready to do the full historical crawl!
MAX_ARTICLES = 300
REQUEST_DELAY = 2
USER_AGENT = "learningProjectPipeline/1.0"

HEADERS = {"User-Agent": USER_AGENT, "Accept-Language": "en-US,en;q=0.9"}

session = requests.Session()
session.headers.update(HEADERS)

# %% [markdown]
# ## HTTP Request Function
#
# The following function retrieves a webpage and handles common HTTP errors.
#
# A delay is applied after each request to reduce the request rate.

# %%
def fetch_page(url):
    """Download a webpage and return its HTML with rate-limit protections."""
    try:
        response = session.get(url, timeout=30)
        print(f"GET {url} -> {response.status_code}")

        if response.status_code == 200:
            time.sleep(REQUEST_DELAY)
            return response.text
        elif response.status_code == 429:
            print("Rate limited. Waiting 10 seconds...")
            time.sleep(10)
            return None
        return None
    except requests.RequestException as e:
        print(f"Request error: {e}")
        return None

# %% [markdown]
# ## URL Normalization
#
# Article URLs are normalized by removing query parameters and fragments.
#
# This prevents the same article from being stored multiple times when it appears with different tracking parameters.

# %%
def normalize_url(url):
    """Clean query strings to prevent tracking duplicates."""
    parsed = urlparse(url)
    return f"{parsed.scheme}://{parsed.netloc}{parsed.path.rstrip('/')}"

# %% [markdown]
# ## Article URL Discovery
#
# The category pages are scanned to identify individual article URLs.
#
# Only URLs belonging to the selected Pluralsight category are retained.

# %%
def extract_article_links(html, category_url):
    """Isolate article links that sit strictly under the current category tree structure."""
    soup = BeautifulSoup(html, "html.parser")
    links = set()
    category_path = urlparse(category_url).path.rstrip("/") + "/"

    for a in soup.find_all("a", href=True):
        url = urljoin(BASE_URL, a["href"])
        url = normalize_url(url)
        parsed_path = urlparse(url).path

        if parsed_path.startswith(category_path):
            links.add(url)
    return links

# %%
def discover_article_urls(category_url, max_pages, max_articles):
    """Scrapes paginated list headers to fetch required candidate links."""
    article_urls = set()

    for page in range(1, max_pages + 1):
        if len(article_urls) >= max_articles:
            break

        page_url = (
            category_url if page == 1 else f"{category_url}?page={page}"
        )
        print(f"Scanning list page {page}...")

        html = fetch_page(page_url)
        if not html:
            continue

        links = extract_article_links(html, category_url)
        article_urls.update(links)

    return sorted(article_urls)[:max_articles]

# %% [markdown]
# ## Article Metadata Extraction
#
# Each article page is parsed to extract standardized metadata.
#
# The extraction uses HTML selectors specific to the Pluralsight article structure.
#
# The Table of Contents, navigation elements, scripts, styles, promotional content, and author biography are removed before article content is extracted.

# %%
def extract_article(url, html, category):
    """Parses individual article structural trees thoroughly across flexible layouts."""
    soup = BeautifulSoup(html, "html.parser")

    # --------------------------------------------------
    # REMOVE UNWANTED LOUT NODES UPFRONT
    # --------------------------------------------------
    toc = soup.find("div", class_="table-of-contents")
    if toc:
        toc.decompose()

    for el in soup.find_all(
        ["nav", "header", "footer", "aside", "script", "style"]
    ):
        el.decompose()

    # --------------------------------------------------
    # CORE METADATA FIELDS PARSING
    # --------------------------------------------------
    title = ""
    h1 = soup.find("h1")
    if h1:
        title = h1.get_text(" ", strip=True)

    description = ""
    meta_desc = soup.find("meta", attrs={"name": "description"})
    if meta_desc:
        description = meta_desc.get("content", "").strip()

    tags = []
    tag_list = soup.find("ul", class_="tag-list-listing")
    if tag_list:
        tags = [
            li.get_text(" ", strip=True)
            for li in tag_list.find_all("li")
            if li.get_text(strip=True)
        ]

    author = ""
    meta_auth = soup.find("meta", attrs={"name": "author"})
    if meta_auth:
        author = meta_auth.get("content", "").strip()

    if not author:
        for element in soup.find_all(["p", "div", "span"]):
            text = element.get_text(" ", strip=True)
            if text.startswith("By ") and len(text) < 100:
                author = text[3:].strip()
                break

    publication_date = ""
    date_el = soup.find("p", class_="date-length-text")
    if date_el:
        text = date_el.get_text(" ", strip=True)
        publication_date = text.split("•")[0].strip()

    # --------------------------------------------------
    # CHRONOLOGICAL CONTENT EXTRACTION ENGINE
    # --------------------------------------------------
    content_parts = []

    # Fallback cascade: Search inside target container blocks or scan the whole body
    content_area = soup.find("article") or soup.find("main") or soup.body

    if content_area:
        for element in content_area.find_all(["h1", "h2", "h3", "h4", "p", "li"]):
            text = element.get_text(" ", strip=True)
            if not text:
                continue

            # Skip header paths, author bylines, or reading time stamps
            if text.startswith("By ") or "Minute Read" in text or "Read article" in text:
                continue
            if "Table of Contents" in text or "Copyright ©" in text:
                continue
            if "Terms of Use" in text or "Privacy Policy" in text:
                continue

            # Skip footer tags lists if found inline
            if element.name == "li":
                parent_classes = " ".join(
                    element.parent.get("class", [])
                ).lower()
                if "tag-list-listing" in parent_classes:
                    continue

            # Clean out promotional blocks text cleanly
            if "Advance your tech skills today" in text or "is a seasoned" in text:
                continue
            if "Subscribe to the newsletter" in text or "Free individual trial" in text:
                continue

            # Append text parts based on tag types
            if element.name in ["h1", "h2", "h3", "h4"]:
                content_parts.append(f"\n{text}\n")
            elif element.name == "li":
                content_parts.append(f"- {text}")
            else:
                content_parts.append(text)

    content = "\n\n".join(content_parts).strip()

    return {
        "source": "Pluralsight",
        "category": category,
        "title": title,
        "author": author,
        "publication_date": publication_date,
        "description": description,
        "tags": tags,
        "url": url,
        "content": content,
        "scraped_at": datetime.now().isoformat(),
    }

# %%
def load_existing_results(output_file):
    if os.path.exists(output_file):
        try:
            with open(output_file, "r", encoding="utf-8") as f:
                return json.load(f)
        except json.JSONDecodeError:
            return []
    return []


def save_results(results, output_file):
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)


def scrape_category(category_name, category_config):
    output_file = category_config["output"]

    print("=" * 60)
    print(f"SCRAPING CATEGORY: {category_name}")
    print("=" * 60)

    existing_results = load_existing_results(output_file)
    existing_urls = {
        item["url"] for item in existing_results if item.get("url")
    }

    print(f"Existing stored records: {len(existing_results)}")

    article_urls = discover_article_urls(
        category_config["url"], category_config["max_pages"], MAX_ARTICLES
    )
    print(f"URLs selected for processing: {len(article_urls)}")

    results = existing_results.copy()

    for i, url in enumerate(article_urls, start=1):
        if url in existing_urls:
            print(f"[{i}/{len(article_urls)}] Already saved, skipping.")
            continue

        print(f"[{i}/{len(article_urls)}] Scraping: {url}")
        html = fetch_page(url)
        if not html:
            continue

        record = extract_article(url, html, category_name)
        if record and record["content"]:  # Ensures we don't save empty records
            results.append(record)
            save_results(results, output_file)
            print(f"Saved: {record['title']}")
        else:
            print("Warning: Article content parsing was empty. Not saving.")

    print(f"Total entries saved for {category_name}: {len(results)}\n")
    return results

# %%
# Iterates through both keys inside the configuration mapping dictionary seamlessly
all_results = {}

for category_name, category_config in CATEGORIES.items():
    results = scrape_category(category_name, category_config)
    all_results[category_name] = results

print("=" * 60)
print("ALL PIPELINE TARGET TASKS ARCHIVED SUCCESSFULLY")
print("=" * 60)
# Out:
# ============================================================
# SCRAPING CATEGORY: AI & Data
# ============================================================
# Existing stored records: 10
# Scanning list page 1...
# GET https://pluralsight.com/resources/blog/ai-and-data -> 200
# Scanning list page 2...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=2 -> 200
# Scanning list page 3...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=3 -> 200
# Scanning list page 4...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=4 -> 200
# Scanning list page 5...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=5 -> 200
# Scanning list page 6...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=6 -> 200
# Scanning list page 7...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=7 -> 200
# Scanning list page 8...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=8 -> 200
# Scanning list page 9...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=9 -> 200
# Scanning list page 10...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=10 -> 200
# Scanning list page 11...
# Request error: HTTPSConnectionPool(host='www.pluralsight.com', port=443): Read timed out. (read timeout=30)
# Scanning list page 12...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=12 -> 200
# Scanning list page 13...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=13 -> 200
# Scanning list page 14...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=14 -> 200
# Scanning list page 15...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=15 -> 200
# Scanning list page 16...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=16 -> 200
# Scanning list page 17...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=17 -> 200
# Scanning list page 18...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=18 -> 200
# Scanning list page 19...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=19 -> 200
# Scanning list page 20...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=20 -> 200
# Scanning list page 21...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=21 -> 200
# Scanning list page 22...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=22 -> 200
# Scanning list page 23...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=23 -> 200
# Scanning list page 24...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=24 -> 200
# Scanning list page 25...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=25 -> 200
# Scanning list page 26...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=26 -> 200
# Scanning list page 27...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=27 -> 200
# Scanning list page 28...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=28 -> 200
# Scanning list page 29...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=29 -> 200
# Scanning list page 30...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=30 -> 200
# Scanning list page 31...
# GET https://pluralsight.com/resources/blog/ai-and-data?page=31 -> 200
# URLs selected for processing: 174
# [1/174] Already saved, skipping.
# [2/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/15-business-analytics-ai-tools
# GET https://pluralsight.com/resources/blog/ai-and-data/15-business-analytics-ai-tools -> 200
# Saved: 15 AI Tools for Business Analytics
# [3/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/2025-ai-career-skills
# GET https://pluralsight.com/resources/blog/ai-and-data/2025-ai-career-skills -> 200
# Saved: AI career success in 2025: key learning paths and skills
# [4/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/2025-ai-tools-trends-tech-sector
# GET https://pluralsight.com/resources/blog/ai-and-data/2025-ai-tools-trends-tech-sector -> 200
# Saved: AI tools and trends in 2025: What tech professionals should know
# [5/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/3-steps-train-machine-learning
# GET https://pluralsight.com/resources/blog/ai-and-data/3-steps-train-machine-learning -> 200
# Saved: How to train a learning model | Pluralsight
# [6/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/AI-agents-for-kubernetes-k8s-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/AI-agents-for-kubernetes-k8s-guide -> 200
# Saved: Understanding AI agents for Kubernetes: Tools, use cases, and more
# [7/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/Business-blocking-OpenAI-ChatGPT-crawling
# GET https://pluralsight.com/resources/blog/ai-and-data/Business-blocking-OpenAI-ChatGPT-crawling -> 200
# Saved: Leaders: Don't prematurely block OpenAI from your websites
# [8/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ChatGPT-Advanced-Data-Analytics
# GET https://pluralsight.com/resources/blog/ai-and-data/ChatGPT-Advanced-Data-Analytics -> 200
# Saved: ChatGPT's Code Interpreter is now Advanced Data Analysis
# [9/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/add-genai-anthropic-claude-api
# GET https://pluralsight.com/resources/blog/ai-and-data/add-genai-anthropic-claude-api -> 200
# Saved: How to add GenAI to your applications with Anthropic Claude API
# [10/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/agentic-ai-explained-btb
# GET https://pluralsight.com/resources/blog/ai-and-data/agentic-ai-explained-btb -> 200
# Saved: Behind the Buzzword: What is agentic AI?
# [11/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/agentic-cli-for-aks-explained
# GET https://pluralsight.com/resources/blog/ai-and-data/agentic-cli-for-aks-explained -> 200
# Saved: Agentic CLI for AKS: FAQs and how to use it
# [12/174] Already saved, skipping.
# [13/174] Already saved, skipping.
# [14/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-bubble-burst
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-bubble-burst -> 200
# Saved: Is the AI bubble going to burst? We don't think so.
# [15/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-business-transformation
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-business-transformation -> 200
# Saved: The path to AI maturity and business transformation
# [16/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-career-guide-2025
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-career-guide-2025 -> 200
# Saved: AI career paths: 2026 job guide
# [17/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-for-customer-service
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-for-customer-service -> 200
# Saved: How to leverage customer service AI tools in your business
# [18/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-generated-text-detection
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-generated-text-detection -> 200
# Saved: How to detect AI-generated text: Ethics and implementation
# [19/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-government-public-sector
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-government-public-sector -> 200
# Saved: AI in government: AI law, use cases, and challenges
# [20/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-gpt-models-differences
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-gpt-models-differences -> 200
# Saved: GPT Base, GPT-3.5 Turbo & GPT-4: What's the difference?
# [21/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-native-mobile-apps
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-native-mobile-apps -> 200
# Saved: What are AI-native mobile apps, and what are their use cases?
# [22/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-native-mobile-apps-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-native-mobile-apps-guide -> 200
# Saved: How to implement an AI-native mobile app: Facial recognition
# [23/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-on-premises-vs-in-cloud
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-on-premises-vs-in-cloud -> 200
# Saved: Cloud AI vs. on-premises AI: Where should my organization run workloads?
# [24/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-data-management
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-data-management -> 200
# Saved: AI readiness: How to improve your data management strategy for AI
# [25/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-governance
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-governance -> 200
# Saved: AI readiness: How to mitigate risk with AI governance
# [26/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-investment-strategy
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-investment-strategy -> 200
# Saved: AI readiness: How to create an AI investment strategy to maximize ROI
# [27/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-skills
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-skills -> 200
# Saved: AI readiness: How to bridge the AI skills gap with upskilling for AI
# [28/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-strategy
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-readiness-ai-strategy -> 200
# Saved: AI readiness: How to enhance your AI strategy development
# [29/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-skills-for-technologists
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-skills-for-technologists -> 200
# Saved: What skills do your technologists need to use AI effectively?
# [30/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-technology-make-buy
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-technology-make-buy -> 200
# Saved: AI technology: The make or buy decision
# [31/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-february-2024
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-february-2024 -> 200
# Saved: AI This Month: Your February AI news roundup
# [32/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-january-2024
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-january-2024 -> 200
# Saved: January news roundup: What's new in the world of AI?
# [33/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-march-2024
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-march-2024 -> 200
# Saved: AI This Month: Your March AI news roundup
# [34/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-may-2024
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-may-2024 -> 200
# Saved: AI This Month: Your May AI news roundup
# [35/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-november-2023
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-this-month-november-2023 -> 200
# Saved: November 2023 AI news roundup: What's new in the world of AI?
# [36/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-tools-for-sales-teams
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-tools-for-sales-teams -> 200
# Saved: How AI sales tools can jump-start new revenue growth
# [37/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-workforce-readiness-state-local
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-workforce-readiness-state-local -> 200
# Saved: Getting AI ready in state and local government
# [38/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ai-workplace-facts-fears
# GET https://pluralsight.com/resources/blog/ai-and-data/ai-workplace-facts-fears -> 200
# Saved: The future of work: Fears and facts about AI in the workplace
# [39/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/aiops-vs-mlops-vs-llmops
# GET https://pluralsight.com/resources/blog/ai-and-data/aiops-vs-mlops-vs-llmops -> 200
# Saved: AIOps vs. MLOps vs. LLMOps: Navigating the future of AI operations
# [40/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/airnyt-react-virtualized-material-ui-cards-for-fast-lists
# GET https://pluralsight.com/resources/blog/ai-and-data/airnyt-react-virtualized-material-ui-cards-for-fast-lists -> 200
# Saved: AirNYT: React-Virtualized + Material UI Cards for Fast Lists
# [41/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/aitm-new-chatgpt-features-assistants-api
# GET https://pluralsight.com/resources/blog/ai-and-data/aitm-new-chatgpt-features-assistants-api -> 200
# Saved: OpenAI DevDay: Diving into ChatGPT's new features, APIs
# [42/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/amazon-aurora-dsql
# GET https://pluralsight.com/resources/blog/ai-and-data/amazon-aurora-dsql -> 200
# Saved: 6 key features of Amazon Aurora DSQL & when leaders should use it
# [43/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/architecting-microservices-agentic-ai
# GET https://pluralsight.com/resources/blog/ai-and-data/architecting-microservices-agentic-ai -> 200
# Saved: Architecting microservices for seamless agentic AI integration
# [44/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/automating-tasks-chatgpt-python
# GET https://pluralsight.com/resources/blog/ai-and-data/automating-tasks-chatgpt-python -> 200
# Saved: How to automate work tasks with ChatGPT and Python
# [45/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/aws-ai-practitioner-certification
# GET https://pluralsight.com/resources/blog/ai-and-data/aws-ai-practitioner-certification -> 200
# Saved: It's time for AWS to debut an AI cert beyond the ML Specialty
# [46/174] Already saved, skipping.
# [47/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/aws-or-azure-ai-leader
# GET https://pluralsight.com/resources/blog/ai-and-data/aws-or-azure-ai-leader -> 200
# Saved: Closing the gap: AWS challenges Azure's apparent AI dominance
# [48/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/azure-ai-search-benefits
# GET https://pluralsight.com/resources/blog/ai-and-data/azure-ai-search-benefits -> 200
# Saved: Azure AI Search: What is it, and how does it help my AI projects?
# [49/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/basic-kubernetes-mutating-webhook-terraform
# GET https://pluralsight.com/resources/blog/ai-and-data/basic-kubernetes-mutating-webhook-terraform -> 200
# Saved: Creating a Basic Kubernetes Mutating Webhook Using Terraform
# [50/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/becoming-a-prompt-engineer
# GET https://pluralsight.com/resources/blog/ai-and-data/becoming-a-prompt-engineer -> 200
# Saved: Prompt Engineering: Is it an actual job?
# [51/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/benefits-aiops-for-organizations
# GET https://pluralsight.com/resources/blog/ai-and-data/benefits-aiops-for-organizations -> 200
# Saved: 7 benefits of AIOps for organizations
# [52/174] Already saved, skipping.
# [53/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/best-ai-models-2026-list
# GET https://pluralsight.com/resources/blog/ai-and-data/best-ai-models-2026-list -> 200
# Saved: The best AI models in 2026: What model to pick for your use case
# [54/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/best-ai-tools-use
# GET https://pluralsight.com/resources/blog/ai-and-data/best-ai-tools-use -> 200
# Saved: The top AI developer tools to use in 2026
# [55/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/best-data-science-courses
# GET https://pluralsight.com/resources/blog/ai-and-data/best-data-science-courses -> 200
# Saved: Best data science courses in 2026
# [56/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/biden-executive-order-artificial-intelligence
# GET https://pluralsight.com/resources/blog/ai-and-data/biden-executive-order-artificial-intelligence -> 200
# Saved: Biden's big AI executive order says a lot about the future of tech
# [57/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/big-data-pipeline
# GET https://pluralsight.com/resources/blog/ai-and-data/big-data-pipeline -> 200
# Saved: Big data pipeline | Pluralsight
# [58/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/big-data-terminology
# GET https://pluralsight.com/resources/blog/ai-and-data/big-data-terminology -> 200
# Saved: Big data terminology | Pluralsight
# [59/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/blocking-ChatGPT-OpenAI-website-crawling
# GET https://pluralsight.com/resources/blog/ai-and-data/blocking-ChatGPT-OpenAI-website-crawling -> 200
# Saved: How to block OpenAI from crawling your website
# [60/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/btb-ai-world-models-explained
# GET https://pluralsight.com/resources/blog/ai-and-data/btb-ai-world-models-explained -> 200
# Saved: Behind the buzzword: What are world models?
# [61/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/build-fast-and-elegant-sites-with-gatsby-netlifycms-and-material-ui
# GET https://pluralsight.com/resources/blog/ai-and-data/build-fast-and-elegant-sites-with-gatsby-netlifycms-and-material-ui -> 200
# Saved: Build Fast and Elegant Sites with Gatsby, NetlifyCMS and Material-UI
# [62/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/caitlin-carpenter-tech-career-pluralsight
# GET https://pluralsight.com/resources/blog/ai-and-data/caitlin-carpenter-tech-career-pluralsight -> 200
# Saved: From agriculture to analytics: How Caitlin Carpenter is growing a tech career with Pluralsight
# [63/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/can-artificial-intelligence-change-education
# GET https://pluralsight.com/resources/blog/ai-and-data/can-artificial-intelligence-change-education -> 200
# Saved: Can AI really change education? Not with our current approach
# [64/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/chat-gpt-plugins-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/chat-gpt-plugins-guide -> 200
# Saved: ChatGPT plugins: How to make ChatGPT smarter
# [65/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/chatgpt-code-interpreter-plugin-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/chatgpt-code-interpreter-plugin-guide -> 200
# Saved: How to use ChatGPT�s New �Code Interpreter� Feature
# [66/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/chatgpt-custom-instructions-feature-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/chatgpt-custom-instructions-feature-guide -> 200
# Saved: ChatGPT Custom Instructions: Get ChatGPT to remember you
# [67/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/chatgpt-data-breach
# GET https://pluralsight.com/resources/blog/ai-and-data/chatgpt-data-breach -> 200
# Saved: All about ChatGPT's first data breach, and how it happened
# [68/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/chatgpt-for-enterprise
# GET https://pluralsight.com/resources/blog/ai-and-data/chatgpt-for-enterprise -> 200
# Saved: ChatGPT for Enterprise: OpenAI's new business offering
# [69/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/chatgpt-writing-viruses
# GET https://pluralsight.com/resources/blog/ai-and-data/chatgpt-writing-viruses -> 200
# Saved: ChatGPT: How Generative AI Can Be Misused
# [70/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/create-ai-products-9-step-framework
# GET https://pluralsight.com/resources/blog/ai-and-data/create-ai-products-9-step-framework -> 200
# Saved: Create AI products systematically with this 9-step framework
# [71/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/creating-agents-with-llamaindex
# GET https://pluralsight.com/resources/blog/ai-and-data/creating-agents-with-llamaindex -> 200
# Saved: How to create agents with LlamaIndex
# [72/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/critical-thinking-ai-misinformation
# GET https://pluralsight.com/resources/blog/ai-and-data/critical-thinking-ai-misinformation -> 200
# Saved: Critical thinking and AI: How to tell what's fake and what's not
# [73/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/critical-thinking-generative-ai-skill
# GET https://pluralsight.com/resources/blog/ai-and-data/critical-thinking-generative-ai-skill -> 200
# Saved: Critical thinking: A must-have soft skill in the age of GenAI
# [74/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/curated-genai-training-courses
# GET https://pluralsight.com/resources/blog/ai-and-data/curated-genai-training-courses -> 200
# Saved: Expert curations: Beginner to intermediate generative AI courses
# [75/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/custom-html-elements-with-vue-js
# GET https://pluralsight.com/resources/blog/ai-and-data/custom-html-elements-with-vue-js -> 200
# Saved: Custom HTML Elements with Vue.JS
# [76/174] Already saved, skipping.
# [77/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/data-analyst-2025-skills
# GET https://pluralsight.com/resources/blog/ai-and-data/data-analyst-2025-skills -> 200
# Saved: Key questions for data analysts seeking future-proof careers
# [78/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/data-career-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/data-career-guide -> 200
# Saved: Data career paths: 2026 job guide
# [79/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/data-informed-decisions
# GET https://pluralsight.com/resources/blog/ai-and-data/data-informed-decisions -> 200
# Saved: 4 levels of analytics
# [80/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/data-pipeline-qa
# GET https://pluralsight.com/resources/blog/ai-and-data/data-pipeline-qa -> 200
# Saved: Data pipeline QA | Pluralsight
# [81/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/deep-learning-neural-networks-explained
# GET https://pluralsight.com/resources/blog/ai-and-data/deep-learning-neural-networks-explained -> 200
# Saved: Deep learning: Understanding how neural networks work
# [82/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/eu-ai-act-for-leaders
# GET https://pluralsight.com/resources/blog/ai-and-data/eu-ai-act-for-leaders -> 200
# Saved: The EU AI Act: What businesses need to know
# [83/174] Already saved, skipping.
# [84/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/federal-workforce-2024-tech-strategy
# GET https://pluralsight.com/resources/blog/ai-and-data/federal-workforce-2024-tech-strategy -> 200
# Saved: Preparing the federal workforce: Tech trends for 2024 (and beyond)
# [85/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/finserv-customer-experience-ai
# GET https://pluralsight.com/resources/blog/ai-and-data/finserv-customer-experience-ai -> 200
# Saved: 3 practical ways to power the FinServ customer experience with AI
# [86/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/future-of-artificial-intelligence-leaders
# GET https://pluralsight.com/resources/blog/ai-and-data/future-of-artificial-intelligence-leaders -> 200
# Saved: The future of artificial intelligence and how leaders can prepare
# [87/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/future-proof-ai-ml-career
# GET https://pluralsight.com/resources/blog/ai-and-data/future-proof-ai-ml-career -> 200
# Saved: How to future-proof a tech career: An AI-first approach
# [88/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/future-proof-data-career
# GET https://pluralsight.com/resources/blog/ai-and-data/future-proof-data-career -> 200
# Saved: How to future-proof your tech career: Data-forward thinking
# [89/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/generative-ai-for-leaders
# GET https://pluralsight.com/resources/blog/ai-and-data/generative-ai-for-leaders -> 200
# Saved: Generative AI for leaders: 6 use cases for your organization
# [90/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/generative-ai-future-of-work
# GET https://pluralsight.com/resources/blog/ai-and-data/generative-ai-future-of-work -> 200
# Saved: How to prepare for generative AI and the future of work
# [91/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/generative-ai-toolkit
# GET https://pluralsight.com/resources/blog/ai-and-data/generative-ai-toolkit -> 200
# Saved: Generative AI toolkit: How to prep your org for AI adoption
# [92/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/get-started-amazon-bedrock
# GET https://pluralsight.com/resources/blog/ai-and-data/get-started-amazon-bedrock -> 200
# Saved: How to get started with Amazon Bedrock
# [93/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/getting-started-langchain
# GET https://pluralsight.com/resources/blog/ai-and-data/getting-started-langchain -> 200
# Saved: Getting started with LangChain: How to run your first application
# [94/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/global-skills-literacy-shortfalls-data-analytics
# GET https://pluralsight.com/resources/blog/ai-and-data/global-skills-literacy-shortfalls-data-analytics -> 200
# Saved: Global skills and literacy shortfalls in data and analytics
# [95/174] Already saved, skipping.
# [96/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/guardrails-for-amazon-bedrock
# GET https://pluralsight.com/resources/blog/ai-and-data/guardrails-for-amazon-bedrock -> 200
# Saved: Guardrails for Amazon Bedrock: Making your AI safe for users
# [97/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/history-and-background-of-javascript-module-loaders
# GET https://pluralsight.com/resources/blog/ai-and-data/history-and-background-of-javascript-module-loaders -> 200
# Saved: History and Background of JavaScript Module Loaders
# [98/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-become-an-mlops-engineer
# GET https://pluralsight.com/resources/blog/ai-and-data/how-become-an-mlops-engineer -> 200
# Saved: How to become an MLOps engineer in 2026
# [99/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-build-chatgpt-application
# GET https://pluralsight.com/resources/blog/ai-and-data/how-build-chatgpt-application -> 200
# Saved: How to Build an Application that uses ChatGPT
# [100/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-build-large-language-model
# GET https://pluralsight.com/resources/blog/ai-and-data/how-build-large-language-model -> 200
# Saved: Creating a large language model from scratch: A beginner's guide
# [101/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-create-custom-gpts-chatgpt
# GET https://pluralsight.com/resources/blog/ai-and-data/how-create-custom-gpts-chatgpt -> 200
# Saved: How to create custom GPTs in ChatGPT
# [102/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-create-ethical-ai-rlhf
# GET https://pluralsight.com/resources/blog/ai-and-data/how-create-ethical-ai-rlhf -> 200
# Saved: Ethical AI: How to make an AI with ethical principles using RLHF
# [103/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-cut-llm-costs-with-metering
# GET https://pluralsight.com/resources/blog/ai-and-data/how-cut-llm-costs-with-metering -> 200
# Saved: Meter before you manage: How to cut LLM costs by up to 85%
# [104/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-run-llm-locally-desktop
# GET https://pluralsight.com/resources/blog/ai-and-data/how-run-llm-locally-desktop -> 200
# Saved: How to run an LLM locally on your desktop
# [105/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-achieve-ai-maturity
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-achieve-ai-maturity -> 200
# Saved: How to achieve AI maturity: Tips from experts at AWS and Fannie Mae
# [106/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-build-microsoft-copilots
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-build-microsoft-copilots -> 200
# Saved: Microsoft Copilot Studio: How to build a no-code AI assistant
# [107/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-get-started-programming-in-r
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-get-started-programming-in-r -> 200
# Saved: How to get started programming in R
# [108/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-implement-contextual-retrieval
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-implement-contextual-retrieval -> 200
# Saved: How to implement contextual retrieval for AI applications
# [109/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-secure-rag-applications-AI
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-secure-rag-applications-AI -> 200
# Saved: Securing your RAG application: A comprehensive guide
# [110/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-use-ai-personalization
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-use-ai-personalization -> 200
# Saved: How to use AI for personalization and 8 other AI use cases
# [111/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-use-aws-glue-crawlers
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-use-aws-glue-crawlers -> 200
# Saved: How to use AWS Glue crawlers with Amazon Athena
# [112/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-use-copilot-dynamics-365
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-use-copilot-dynamics-365 -> 200
# Saved: How to use Copilot in Microsoft Dynamics 365 for max productivity
# [113/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-use-copilot-in-power-apps
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-use-copilot-in-power-apps -> 200
# Saved: How to use Copilot to build a canvas app in Microsoft Power Apps
# [114/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-to-use-dall-e-midjourney
# GET https://pluralsight.com/resources/blog/ai-and-data/how-to-use-dall-e-midjourney -> 200
# Saved: How to use AI image generators DALL-E and Midjourney
# [115/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-use-chatgpt-learning
# GET https://pluralsight.com/resources/blog/ai-and-data/how-use-chatgpt-learning -> 200
# Saved: How to Use ChatGPT for learning
# [116/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/how-use-microsoft-copilot-work
# GET https://pluralsight.com/resources/blog/ai-and-data/how-use-microsoft-copilot-work -> 200
# Saved: Microsoft 365 Copilot: A practical guide to AI-powered workflows
# [117/174] Already saved, skipping.
# [118/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/integrate-genai-applications-openai
# GET https://pluralsight.com/resources/blog/ai-and-data/integrate-genai-applications-openai -> 200
# Saved: How to integrate generative AI into your applications
# [119/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/is-prompt-engineering-dead
# GET https://pluralsight.com/resources/blog/ai-and-data/is-prompt-engineering-dead -> 200
# Saved: Is prompt engineering dead? No, and it won't be for a long time
# [120/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/javascript-functions-as-first-class-objects
# GET https://pluralsight.com/resources/blog/ai-and-data/javascript-functions-as-first-class-objects -> 200
# Saved: Functions as First-Class Objects in JavaScript: Why Does This Matter?
# [121/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/langchain-langgraph-agentic-ai-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/langchain-langgraph-agentic-ai-guide -> 200
# Saved: LangChain LangGraph Agentic AI Guide
# [122/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/langchain-local-vector-database-tutorial
# GET https://pluralsight.com/resources/blog/ai-and-data/langchain-local-vector-database-tutorial -> 200
# Saved: Vector Databases: Building a Local LangChain Store in Python
# [123/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/leaders-guide-data-strategy-for-AI
# GET https://pluralsight.com/resources/blog/ai-and-data/leaders-guide-data-strategy-for-AI -> 200
# Saved: A leader's guide for building a modern data strategy for AI
# [124/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/leaders-look-at-ai
# GET https://pluralsight.com/resources/blog/ai-and-data/leaders-look-at-ai -> 200
# Saved: Leaders look at AI: Data on skills gaps, AI tools, and new AI roles
# [125/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/llms-real-world-applications
# GET https://pluralsight.com/resources/blog/ai-and-data/llms-real-world-applications -> 200
# Saved: LLMs in action: How to use them for real-world applications
# [126/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/llms-tensorflow-keras-hugging-face
# GET https://pluralsight.com/resources/blog/ai-and-data/llms-tensorflow-keras-hugging-face -> 200
# Saved: LLMs: Transfer Learning with TensorFlow, Keras, Hugging Face
# [127/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/local-models-langchain-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/local-models-langchain-guide -> 200
# Saved: Bringing AI on-prem: How to use local models in LangChain
# [128/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/machine-learning-paradigms-explained
# GET https://pluralsight.com/resources/blog/ai-and-data/machine-learning-paradigms-explained -> 200
# Saved: The 5 different types of machine learning paradigms, explained
# [129/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/manage-javascript-canvas-elements
# GET https://pluralsight.com/resources/blog/ai-and-data/manage-javascript-canvas-elements -> 200
# Saved: Manage Your Javascript Canvas Elements
# [130/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/multi-agent-systems-mcp-AI
# GET https://pluralsight.com/resources/blog/ai-and-data/multi-agent-systems-mcp-AI -> 200
# Saved: Multi-agent systems with MCP: Building AI teams that share tools
# [131/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/multimodal-agentic-rag-assistant-guide
# GET https://pluralsight.com/resources/blog/ai-and-data/multimodal-agentic-rag-assistant-guide -> 200
# Saved: How to build a multimodal agentic RAG AI assistant: A guide
# [132/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/new-aws-aif-c01-exam
# GET https://pluralsight.com/resources/blog/ai-and-data/new-aws-aif-c01-exam -> 200
# Saved: AWS AI Certification: Your Guide to AIF-C01 Exam Success
# [133/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/new-aws-c01-exam
# GET https://pluralsight.com/resources/blog/ai-and-data/new-aws-c01-exam -> 200
# Saved: AWS Certified AI Practitioner (AIF-C01)
# [134/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/ollama-vs-chatgpt
# GET https://pluralsight.com/resources/blog/ai-and-data/ollama-vs-chatgpt -> 200
# Saved: Ollama: The Docker for LLMs and how it compares to ChatGPT
# [135/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/omnimodal-ai
# GET https://pluralsight.com/resources/blog/ai-and-data/omnimodal-ai -> 200
# Saved: Omnimodal AI: Why tomorrow's AI will have all five senses
# [136/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/openai-assistants
# GET https://pluralsight.com/resources/blog/ai-and-data/openai-assistants -> 200
# Saved: OpenAI Assistants: How to create and use them
# [137/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/openai-devday-2023-takeaways
# GET https://pluralsight.com/resources/blog/ai-and-data/openai-devday-2023-takeaways -> 200
# Saved: OpenAI DevDay 2023: 5 Key Takeaways from the conference
# [138/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/pigeon-vs-ai-associated-learning
# GET https://pluralsight.com/resources/blog/ai-and-data/pigeon-vs-ai-associated-learning -> 200
# Saved: Pigeon VS AI: Is a wild bird smarter than artificial intelligence?
# [139/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/pil-ai-ml-success
# GET https://pluralsight.com/resources/blog/ai-and-data/pil-ai-ml-success -> 200
# Saved: Data science, AI, and ML | Pluralsight
# [140/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/pil-leveraging-data-to-enhance-the-developer-experience
# GET https://pluralsight.com/resources/blog/ai-and-data/pil-leveraging-data-to-enhance-the-developer-experience -> 200
# Saved: Success through people and data
# [141/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/prompt-engineering-techniques
# GET https://pluralsight.com/resources/blog/ai-and-data/prompt-engineering-techniques -> 200
# Saved: Prompt engineering guide: Techniques, examples, and use cases
# [142/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/quandry-of-agentic-ai
# GET https://pluralsight.com/resources/blog/ai-and-data/quandry-of-agentic-ai -> 200
# Saved: A view from the Rubicon and the quandary of agentic AI
# [143/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/resiliency-ai-age
# GET https://pluralsight.com/resources/blog/ai-and-data/resiliency-ai-age -> 200
# Saved: Resiliency in an AI age: Key AI skills for tech professionals
# [144/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/responsible-ai-data-drift-azure-ml
# GET https://pluralsight.com/resources/blog/ai-and-data/responsible-ai-data-drift-azure-ml -> 200
# Saved: Responsible AI: How to manage data drift in Azure ML
# [145/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/responsible-innovation-llms
# GET https://pluralsight.com/resources/blog/ai-and-data/responsible-innovation-llms -> 200
# Saved: A blueprint for responsible innovation with Large Language Models
# [146/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/spring-ai-speech-to-text
# GET https://pluralsight.com/resources/blog/ai-and-data/spring-ai-speech-to-text -> 200
# Saved: Adding speech to text in your application with Spring AI
# [147/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/tech-skill-development-and-the-route-to-success-for-financial-services
# GET https://pluralsight.com/resources/blog/ai-and-data/tech-skill-development-and-the-route-to-success-for-financial-services -> 200
# Saved: Tech skill development and the route to success for financial services
# [148/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/technology-specialist-generalist-tshaped
# GET https://pluralsight.com/resources/blog/ai-and-data/technology-specialist-generalist-tshaped -> 200
# Saved: Should I become a technology specialist or generalist?
# [149/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/top-soft-skills-tech-2023
# GET https://pluralsight.com/resources/blog/ai-and-data/top-soft-skills-tech-2023 -> 200
# Saved: Work in tech? The top soft skills to develop in 2023
# [150/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/top-tech-skills-2023
# GET https://pluralsight.com/resources/blog/ai-and-data/top-tech-skills-2023 -> 200
# Saved: Pluralsight's top tech skills for 2023
# [151/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/using-ai-hr-tools-hiring
# GET https://pluralsight.com/resources/blog/ai-and-data/using-ai-hr-tools-hiring -> 200
# Saved: Using AI for hiring: HR tools and guidance for eliminating AI bias
# [152/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/using-jquery-css-method
# GET https://pluralsight.com/resources/blog/ai-and-data/using-jquery-css-method -> 200
# Saved: How to change CSS using jQuery?
# [153/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/vibe-coding-explained-btb
# GET https://pluralsight.com/resources/blog/ai-and-data/vibe-coding-explained-btb -> 200
# Saved: Behind the Buzzword: What is vibe coding?
# [154/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-are-mcp-servers-btb
# GET https://pluralsight.com/resources/blog/ai-and-data/what-are-mcp-servers-btb -> 200
# Saved: Behind the Buzzword: What is MCP?
# [155/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-are-transformers-generative-ai
# GET https://pluralsight.com/resources/blog/ai-and-data/what-are-transformers-generative-ai -> 200
# Saved: What are Transformers in Generative AI
# [156/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-agi-btb
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-agi-btb -> 200
# Saved: Behind the buzzword: What is AGI?
# [157/174] Already saved, skipping.
# [158/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-amazon-bedrock
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-amazon-bedrock -> 200
# Saved: What is Amazon Bedrock? The custom GenAI building service
# [159/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-amazon-q
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-amazon-q -> 200
# Saved: What is Amazon Q? The AI chatbot for companies
# [160/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-apache-kafka
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-apache-kafka -> 200
# Saved: What is Apache Kafka? An introductory guide
# [161/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-chatgpt-agent
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-chatgpt-agent -> 200
# Saved: What is a ChatGPT Agent and How Can I Use It
# [162/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-chatgpt-generative-ai
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-chatgpt-generative-ai -> 200
# Saved: What are ChatGPT and Generative AI (and how can I use them)?
# [163/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-claude-code
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-claude-code -> 200
# Saved: What is Claude Code?
# [164/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-claude-mythos
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-claude-mythos -> 200
# Saved: What is Claude Mythos?
# [165/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-contextual-retrieval-for-leaders
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-contextual-retrieval-for-leaders -> 200
# Saved: What is contextual retrieval? What leaders need to know
# [166/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-llmops
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-llmops -> 200
# Saved: What is LLMOps Compared to MLOps
# [167/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-rag
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-rag -> 200
# Saved: What is RAG: Definition, use cases, and how to implement it
# [168/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/what-is-synthetic-data-ml
# GET https://pluralsight.com/resources/blog/ai-and-data/what-is-synthetic-data-ml -> 200
# Saved: Synthetic data: The future of machine learning?
# [169/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/whats-missing-pacing-the-frontier
# GET https://pluralsight.com/resources/blog/ai-and-data/whats-missing-pacing-the-frontier -> 200
# Saved: What’s missing from Pacing the Frontier, the open letter about AI development
# [170/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/why-ai-projects-never-finish
# GET https://pluralsight.com/resources/blog/ai-and-data/why-ai-projects-never-finish -> 200
# Saved: AI projects are never complete: deployment is just the beginning
# [171/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/why-developers-should-embrace-chatgpt
# GET https://pluralsight.com/resources/blog/ai-and-data/why-developers-should-embrace-chatgpt -> 200
# Saved: Alex Lawrence on why developers and students should embrace ChatGPT
# [172/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/why-study-ai-skeptic
# GET https://pluralsight.com/resources/blog/ai-and-data/why-study-ai-skeptic -> 200
# Saved: Why you should study AI even if you're an AI skeptic
# [173/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/workforce-readiness-ai-skills
# GET https://pluralsight.com/resources/blog/ai-and-data/workforce-readiness-ai-skills -> 200
# Saved: Federal agencies: How to become workforce ready with AI skills
# [174/174] Scraping: https://pluralsight.com/resources/blog/ai-and-data/writing-generative-ai-usage-policy
# GET https://pluralsight.com/resources/blog/ai-and-data/writing-generative-ai-usage-policy -> 200
# Saved: Organizations, don't ban generative AI: Write a usage policy
# Total entries saved for AI & Data: 174
#
# ============================================================
# SCRAPING CATEGORY: Cloud
# ============================================================
# Existing stored records: 10
# Scanning list page 1...
# GET https://pluralsight.com/resources/blog/cloud -> 200
# Scanning list page 2...
# GET https://pluralsight.com/resources/blog/cloud?page=2 -> 200
# Scanning list page 3...
# GET https://pluralsight.com/resources/blog/cloud?page=3 -> 200
# Scanning list page 4...
# GET https://pluralsight.com/resources/blog/cloud?page=4 -> 200
# Scanning list page 5...
# GET https://pluralsight.com/resources/blog/cloud?page=5 -> 200
# Scanning list page 6...
# GET https://pluralsight.com/resources/blog/cloud?page=6 -> 200
# Scanning list page 7...
# GET https://pluralsight.com/resources/blog/cloud?page=7 -> 200
# Scanning list page 8...
# GET https://pluralsight.com/resources/blog/cloud?page=8 -> 200
# Scanning list page 9...
# GET https://pluralsight.com/resources/blog/cloud?page=9 -> 200
# Scanning list page 10...
# GET https://pluralsight.com/resources/blog/cloud?page=10 -> 200
# Scanning list page 11...
# GET https://pluralsight.com/resources/blog/cloud?page=11 -> 200
# Scanning list page 12...
# GET https://pluralsight.com/resources/blog/cloud?page=12 -> 200
# Scanning list page 13...
# GET https://pluralsight.com/resources/blog/cloud?page=13 -> 200
# Scanning list page 14...
# GET https://pluralsight.com/resources/blog/cloud?page=14 -> 200
# Scanning list page 15...
# GET https://pluralsight.com/resources/blog/cloud?page=15 -> 200
# Scanning list page 16...
# GET https://pluralsight.com/resources/blog/cloud?page=16 -> 200
# Scanning list page 17...
# GET https://pluralsight.com/resources/blog/cloud?page=17 -> 200
# Scanning list page 18...
# GET https://pluralsight.com/resources/blog/cloud?page=18 -> 200
# Scanning list page 19...
# GET https://pluralsight.com/resources/blog/cloud?page=19 -> 200
# Scanning list page 20...
# GET https://pluralsight.com/resources/blog/cloud?page=20 -> 200
# Scanning list page 21...
# GET https://pluralsight.com/resources/blog/cloud?page=21 -> 200
# Scanning list page 22...
# GET https://pluralsight.com/resources/blog/cloud?page=22 -> 200
# Scanning list page 23...
# GET https://pluralsight.com/resources/blog/cloud?page=23 -> 200
# Scanning list page 24...
# GET https://pluralsight.com/resources/blog/cloud?page=24 -> 200
# Scanning list page 25...
# GET https://pluralsight.com/resources/blog/cloud?page=25 -> 200
# Scanning list page 26...
# GET https://pluralsight.com/resources/blog/cloud?page=26 -> 200
# Scanning list page 27...
# GET https://pluralsight.com/resources/blog/cloud?page=27 -> 200
# Scanning list page 28...
# GET https://pluralsight.com/resources/blog/cloud?page=28 -> 200
# Scanning list page 29...
# GET https://pluralsight.com/resources/blog/cloud?page=29 -> 200
# Scanning list page 30...
# GET https://pluralsight.com/resources/blog/cloud?page=30 -> 200
# Scanning list page 31...
# GET https://pluralsight.com/resources/blog/cloud?page=31 -> 200
# Scanning list page 32...
# ...
# Saved: Securing your multi-cloud Terraform pipelines with policy-as-code
# [240/300] Scraping: https://pluralsight.com/resources/blog/cloud/selected-cloud-training-courses
# GET https://pluralsight.com/resources/blog/cloud/selected-cloud-training-courses -> 200
# Saved: Our expert-selected cloud training courses and certifications
# [241/300] Scraping: https://pluralsight.com/resources/blog/cloud/serverless-api-aws-cdk
# GET https://pluralsight.com/resources/blog/cloud/serverless-api-aws-cdk -> 200
# Saved: Building a serverless API with the AWS CDK
# [242/300] Scraping: https://pluralsight.com/resources/blog/cloud/serverless-browser-automation-with-aws-lambda-and-puppeteer
# GET https://pluralsight.com/resources/blog/cloud/serverless-browser-automation-with-aws-lambda-and-puppeteer -> 200
# Saved: Serverless browser automation with AWS Lambda and Puppeteer
# [243/300] Scraping: https://pluralsight.com/resources/blog/cloud/serving-dynamic-website-content-with-serverless-architecture
# GET https://pluralsight.com/resources/blog/cloud/serving-dynamic-website-content-with-serverless-architecture -> 200
# Saved: Serving dynamic website content with serverless architecture
# [244/300] Scraping: https://pluralsight.com/resources/blog/cloud/sharon-prince-customer-story
# GET https://pluralsight.com/resources/blog/cloud/sharon-prince-customer-story -> 200
# Saved: "I got every AWS Certificate in under 3 months": How Sharōn Prince did it with Pluralsight
# [245/300] Scraping: https://pluralsight.com/resources/blog/cloud/spec-driven-development-amazon-kiro
# GET https://pluralsight.com/resources/blog/cloud/spec-driven-development-amazon-kiro -> 200
# Saved: Spec-driven Development in practice: Building a serverless URL shortener with Amazon Kiro
# [246/300] Scraping: https://pluralsight.com/resources/blog/cloud/ssh-and-scp-howto-tips-tricks
# GET https://pluralsight.com/resources/blog/cloud/ssh-and-scp-howto-tips-tricks -> 200
# Saved: How to use SSH and SCP Linux Commands: Tips and Tricks
# [247/300] Scraping: https://pluralsight.com/resources/blog/cloud/storage-showdown-aws-vs-azure-vs-gcp-cloud-comparison
# GET https://pluralsight.com/resources/blog/cloud/storage-showdown-aws-vs-azure-vs-gcp-cloud-comparison -> 200
# Saved: Storage services compared: AWS vs Azure vs GCP
# [248/300] Scraping: https://pluralsight.com/resources/blog/cloud/system-log-aggregation-with-the-elastic-stack
# GET https://pluralsight.com/resources/blog/cloud/system-log-aggregation-with-the-elastic-stack -> 200
# Saved: System Log Aggregation with the Elastic Stack
# [249/300] Scraping: https://pluralsight.com/resources/blog/cloud/teams-learn-azure-fundamentals
# GET https://pluralsight.com/resources/blog/cloud/teams-learn-azure-fundamentals -> 200
# Saved: Help teams learn Azure fundamentals (with course recommendations)
# [250/300] Scraping: https://pluralsight.com/resources/blog/cloud/tech-skills-day-cloud-track-2022
# GET https://pluralsight.com/resources/blog/cloud/tech-skills-day-cloud-track-2022 -> 200
# Saved: Tech Skills Day cloud track 2022: Learns and loves
# [251/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-awk-command-bash-basics
# GET https://pluralsight.com/resources/blog/cloud/the-awk-command-bash-basics -> 200
# Saved: How to use BASH AWK command on Linux
# [252/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-azure-dictionary-of-pain-five-of-azures-toughest-cloud-topics
# GET https://pluralsight.com/resources/blog/cloud/the-azure-dictionary-of-pain-five-of-azures-toughest-cloud-topics -> 200
# Saved: The Azure Dictionary of Pain: Five Of Azure's Toughest Cloud Topics
# [253/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-career-changing-art-of-reading-the-docs
# GET https://pluralsight.com/resources/blog/cloud/the-career-changing-art-of-reading-the-docs -> 200
# Saved: The career-changing art of reading the docs
# [254/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-cloud-dictionary-of-pain-five-of-awss-toughest-cloud-topics
# GET https://pluralsight.com/resources/blog/cloud/the-cloud-dictionary-of-pain-five-of-awss-toughest-cloud-topics -> 200
# Saved: The Cloud Dictionary of Pain: Five Of AWS's Toughest Cloud Topics
# [255/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-cloud-dictionary-of-pain-five-of-google-clouds-toughest-topics
# GET https://pluralsight.com/resources/blog/cloud/the-cloud-dictionary-of-pain-five-of-google-clouds-toughest-topics -> 200
# Saved: The Cloud Dictionary of Pain: Five Of Google Cloud's Toughest Topics
# [256/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-students-guide-to-getting-started-with-cloud
# GET https://pluralsight.com/resources/blog/cloud/the-students-guide-to-getting-started-with-cloud -> 200
# Saved: The student's guide to getting started with cloud
# [257/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-top-devops-skills-people-are-learning-at-a-cloud-guru-right-now
# GET https://pluralsight.com/resources/blog/cloud/the-top-devops-skills-people-are-learning-at-a-cloud-guru-right-now -> 200
# Saved: Key DevOps skills people are learning at A Cloud Guru right now
# [258/300] Scraping: https://pluralsight.com/resources/blog/cloud/the-value-of-an-aws-certification
# GET https://pluralsight.com/resources/blog/cloud/the-value-of-an-aws-certification -> 200
# Saved: The Value of an AWS Certification
# [259/300] Scraping: https://pluralsight.com/resources/blog/cloud/three-keys-to-building-cloud-fluency-across-your-organization
# GET https://pluralsight.com/resources/blog/cloud/three-keys-to-building-cloud-fluency-across-your-organization -> 200
# Saved: Three keys to building cloud fluency across your organization
# [260/300] Scraping: https://pluralsight.com/resources/blog/cloud/tmux-cheat-sheet
# GET https://pluralsight.com/resources/blog/cloud/tmux-cheat-sheet -> 200
# Saved: tmux Cheat Sheet | Session, Window & Pane Shortcuts
# [261/300] Scraping: https://pluralsight.com/resources/blog/cloud/to-modernize-your-legacy-apps-first-stop-being-ashamed-of-them
# GET https://pluralsight.com/resources/blog/cloud/to-modernize-your-legacy-apps-first-stop-being-ashamed-of-them -> 200
# Saved: To modernize your legacy apps, first stop being ashamed of them
# [262/300] Scraping: https://pluralsight.com/resources/blog/cloud/to-succeed-in-devops-careers-level-up-these-skills
# GET https://pluralsight.com/resources/blog/cloud/to-succeed-in-devops-careers-level-up-these-skills -> 200
# Saved: Top DevOps skills and technologies (and how to learn them)
# [263/300] Scraping: https://pluralsight.com/resources/blog/cloud/top-5-tips-for-troubleshooting-network-connectivity-in-aws
# GET https://pluralsight.com/resources/blog/cloud/top-5-tips-for-troubleshooting-network-connectivity-in-aws -> 200
# Saved: Top 5 tips for troubleshooting network connectivity in AWS
# [264/300] Scraping: https://pluralsight.com/resources/blog/cloud/top-cloud-certifications-team-development
# GET https://pluralsight.com/resources/blog/cloud/top-cloud-certifications-team-development -> 200
# Saved: Top cloud certifications for team development
# [265/300] Scraping: https://pluralsight.com/resources/blog/cloud/trying-risk-free-cloud-services
# GET https://pluralsight.com/resources/blog/cloud/trying-risk-free-cloud-services -> 200
# Saved: How to try out cloud services without hurting your wallet
# [266/300] Scraping: https://pluralsight.com/resources/blog/cloud/turn-cloud-investments-into-roi
# GET https://pluralsight.com/resources/blog/cloud/turn-cloud-investments-into-roi -> 200
# Saved: Turn cloud investments into ROI
# [267/300] Scraping: https://pluralsight.com/resources/blog/cloud/twelve-factor-apps-in-kubernetes
# GET https://pluralsight.com/resources/blog/cloud/twelve-factor-apps-in-kubernetes -> 200
# Saved: Twelve-Factor Apps in Kubernetes
# [268/300] Scraping: https://pluralsight.com/resources/blog/cloud/ubuntu-22-04-lts-is-here
# GET https://pluralsight.com/resources/blog/cloud/ubuntu-22-04-lts-is-here -> 200
# Saved: Ubuntu 22.04 LTS is here!
# [269/300] Scraping: https://pluralsight.com/resources/blog/cloud/understanding-authentication-in-openshift-4
# GET https://pluralsight.com/resources/blog/cloud/understanding-authentication-in-openshift-4 -> 200
# Saved: Understanding authentication in OpenShift 4
# [270/300] Scraping: https://pluralsight.com/resources/blog/cloud/using-creating-aws-cdk-constructs
# GET https://pluralsight.com/resources/blog/cloud/using-creating-aws-cdk-constructs -> 200
# Saved: Using and Creating AWS CDK Constructs
# [271/300] Scraping: https://pluralsight.com/resources/blog/cloud/vertically-scaling-amazon-eks
# GET https://pluralsight.com/resources/blog/cloud/vertically-scaling-amazon-eks -> 200
# Saved: Vertically scaling your Amazon EKS deployments
# [272/300] Scraping: https://pluralsight.com/resources/blog/cloud/virtual-reality-explained
# GET https://pluralsight.com/resources/blog/cloud/virtual-reality-explained -> 200
# Saved: Virtual reality, real possibilities: What is it, and what's all the fuss?
# [273/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-are-the-top-paying-microsoft-azure-certifications
# GET https://pluralsight.com/resources/blog/cloud/what-are-the-top-paying-microsoft-azure-certifications -> 200
# Saved: What are the top-paying Microsoft Azure certifications?
# [274/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-does-the-terraform-1-0-release-mean-for-you
# GET https://pluralsight.com/resources/blog/cloud/what-does-the-terraform-1-0-release-mean-for-you -> 200
# Saved: What does the Terraform 1.0 release mean for you?
# [275/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-a-cloud-architect-and-how-do-you-become-one
# GET https://pluralsight.com/resources/blog/cloud/what-is-a-cloud-architect-and-how-do-you-become-one -> 200
# Saved: What is a Cloud Architect (and how do you become one)?
# [276/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-amazon-kinesis
# GET https://pluralsight.com/resources/blog/cloud/what-is-amazon-kinesis -> 200
# Saved: What is Amazon Kinesis, and how does it work?
# [277/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-amazon-web-services-aws
# GET https://pluralsight.com/resources/blog/cloud/what-is-amazon-web-services-aws -> 200
# Saved: What is AWS? Amazon Web Services Guide
# [278/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-cloud-migration
# GET https://pluralsight.com/resources/blog/cloud/what-is-cloud-migration -> 200
# Saved: What is Cloud Migration?
# [279/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-cloud-transformation-why-embrace-it
# GET https://pluralsight.com/resources/blog/cloud/what-is-cloud-transformation-why-embrace-it -> 200
# Saved: What is cloud transformation & why should you embrace it?
# [280/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-devrel
# GET https://pluralsight.com/resources/blog/cloud/what-is-devrel -> 200
# Saved: What is DevRel?
# [281/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-dna-computing-technology
# GET https://pluralsight.com/resources/blog/cloud/what-is-dna-computing-technology -> 200
# Saved: What is DNA computing technology?
# [282/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-go-an-intro-to-googles-go-programming-language-aka-golang
# GET https://pluralsight.com/resources/blog/cloud/what-is-go-an-intro-to-googles-go-programming-language-aka-golang -> 200
# Saved: An Intro to Google's Go Programming Language
# [283/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-google-cloud-platform-gcp
# GET https://pluralsight.com/resources/blog/cloud/what-is-google-cloud-platform-gcp -> 200
# Saved: What is Google Cloud Platform (GCP)?
# [284/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-kusto-query-language-kql
# GET https://pluralsight.com/resources/blog/cloud/what-is-kusto-query-language-kql -> 200
# Saved: What is Kusto Query Language (KQL)
# [285/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-linux
# GET https://pluralsight.com/resources/blog/cloud/what-is-linux -> 200
# Saved: What is Linux?
# [286/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-machine-learning-as-a-service-mlaas
# GET https://pluralsight.com/resources/blog/cloud/what-is-machine-learning-as-a-service-mlaas -> 200
# Saved: What is machine learning as a service (MLaaS)?
# [287/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-microsoft-azure
# GET https://pluralsight.com/resources/blog/cloud/what-is-microsoft-azure -> 200
# Saved: What is Microsoft Azure? The cloud platform explained.
# [288/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-oracle-cloud-and-why-should-you-use-it
# GET https://pluralsight.com/resources/blog/cloud/what-is-oracle-cloud-and-why-should-you-use-it -> 200
# Saved: What is Oracle Cloud, and why should you use it?
# [289/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-serverless
# GET https://pluralsight.com/resources/blog/cloud/what-is-serverless -> 200
# Saved: What is serverless?
# [290/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-the-php-programming-language
# GET https://pluralsight.com/resources/blog/cloud/what-is-the-php-programming-language -> 200
# Saved: What is the PHP programming language?
# [291/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-vmware-hybrid-cloud
# GET https://pluralsight.com/resources/blog/cloud/what-is-vmware-hybrid-cloud -> 200
# Saved: What is VMware Hybrid Cloud?
# [292/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-is-web3-explained
# GET https://pluralsight.com/resources/blog/cloud/what-is-web3-explained -> 200
# Saved: Web3 explained: What is it, and is it worth all the fuss?
# [293/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-to-do-cloud-outages
# GET https://pluralsight.com/resources/blog/cloud/what-to-do-cloud-outages -> 200
# Saved: 5 steps to take when the cloud goes down
# [294/300] Scraping: https://pluralsight.com/resources/blog/cloud/what-you-need-to-know-about-aws-app-runner
# GET https://pluralsight.com/resources/blog/cloud/what-you-need-to-know-about-aws-app-runner -> 200
# Saved: Magic beanstalk? What you need to know about AWS App Runner
# [295/300] Scraping: https://pluralsight.com/resources/blog/cloud/whats-the-best-aws-training-for-beginners
# GET https://pluralsight.com/resources/blog/cloud/whats-the-best-aws-training-for-beginners -> 200
# Saved: What's the best AWS training for beginners?
# [296/300] Scraping: https://pluralsight.com/resources/blog/cloud/which-container-development-certification-is-best-for-me
# GET https://pluralsight.com/resources/blog/cloud/which-container-development-certification-is-best-for-me -> 200
# Saved: Which container development certification is best for me?
# [297/300] Scraping: https://pluralsight.com/resources/blog/cloud/which-google-cloud-certification-is-best-for-me
# GET https://pluralsight.com/resources/blog/cloud/which-google-cloud-certification-is-best-for-me -> 200
# Saved: Which Google Cloud certification is best for me?
# [298/300] Scraping: https://pluralsight.com/resources/blog/cloud/which-kubernetes-distribution-is-right-for-you
# GET https://pluralsight.com/resources/blog/cloud/which-kubernetes-distribution-is-right-for-you -> 200
# Saved: Which Kubernetes distribution is right for you?
# [299/300] Scraping: https://pluralsight.com/resources/blog/cloud/why-learn-multiple-cloud-platforms
# GET https://pluralsight.com/resources/blog/cloud/why-learn-multiple-cloud-platforms -> 200
# Saved: Multicloud Fluency: 5 reasons to learn multiple clouds
# [300/300] Scraping: https://pluralsight.com/resources/blog/cloud/why-use-aws-marketplace
# GET https://pluralsight.com/resources/blog/cloud/why-use-aws-marketplace -> 200
# Saved: From procurement pain to innovation gain: Why use the AWS Marketplace
# Total entries saved for Cloud: 298
#
# ============================================================
# ALL PIPELINE TARGET TASKS ARCHIVED SUCCESSFULLY
# ============================================================

# %% [markdown]
# ## Extraction Results
#
# The extracted records are stored as raw JSON files under `../data/raw/`.
#
# The files produced by this notebook are:
#
# - `../data/raw/pluralsight_ai_data_articles.json`
# - `../data/raw/pluralsight_cloud_articles.json`
#
# These files serve as the input to Task 2.
